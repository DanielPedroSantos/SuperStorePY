# %% [markdown]
# # Realizando analise exploratorio

# %%
# importando as bibliotecas necessárias

import pandas as pd
import numpy as np

# %%
# Importando os dados

df = pd.read_excel('/home/danielpedro/Python/Projetos/SuperStorePY/Dataset/Sample - Superstore.xlsx', sheet_name='Orders')

# %%
# Verificando o formato dos dados e se tem dados nulos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             9994 non-null   int64
#  1   Id_Pedido      9994 non-null   object
#  2   Data_Pedido    9994 non-null   datetime64[ns]
#  3   Data_Envio     9994 non-null   datetime64[ns]
#  4   Modo_Envio     9994 non-null   object
#  5   Id_Cliente     9994 non-null   object
#  6   Nome_Cliente   9994 non-null   object
#  7   Segmento       9994 non-null   object
#  8   Pais           9994 non-null   object
#  9   Cidade         9994 non-null   object
#  10  Estado         9994 non-null   object
#  11  CE             9994 non-null   int64
#  12  Regiao         9994 non-null   object
#  13  Id_Produto     9994 non-null   object
#  14  Categoria      9994 non-null   object
#  15  Sub_Categoria  9994 non-null   object
#  16  Nome_Produto   9994 non-null   object
# ...

# %%
#  Vereificando o numero de linhas e colunas

df.shape
# Out:
# (9994, 21)

# %%
#  Verificando os nomes das colunas

df.columns
# Out:
# Index(['Id', 'Id_Pedido', 'Data_Pedido', 'Data_Envio', 'Modo_Envio',
#        'Id_Cliente', 'Nome_Cliente', 'Segmento', 'Pais', 'Cidade', 'Estado',
#        'CE', 'Regiao', 'Id_Produto', 'Categoria', 'Sub_Categoria',
#        'Nome_Produto', 'Valor_Venda', 'Quantidade', 'Desconto', 'Lucro'],
#       dtype='object')

# %%
#Verificando as 5 primeiras linhas 

df.head(5)
# Out:
#      Id       Id_Pedido Data_Pedido Data_Envio      Modo_Envio Id_Cliente  \
# 0   646  CA-2017-126221  2017-12-30 2018-01-05  Standard Class   CC-12430
# 1   907  CA-2017-143259  2017-12-30 2018-01-03  Standard Class   PO-18865
# 2   908  CA-2017-143259  2017-12-30 2018-01-03  Standard Class   PO-18865
# 3   909  CA-2017-143259  2017-12-30 2018-01-03  Standard Class   PO-18865
# 4  1297  CA-2017-115427  2017-12-30 2018-01-03  Standard Class   EB-13975
#
#         Nome_Cliente     Segmento           Pais         Cidade  ...     CE  \
# 0        Chuck Clark  Home Office  United States       Columbus  ...  47201
# 1  Patrick O'Donnell     Consumer  United States  New York City  ...  10009
# 2  Patrick O'Donnell     Consumer  United States  New York City  ...  10009
# 3  Patrick O'Donnell     Consumer  United States  New York City  ...  10009
# 4         Erica Bern    Corporate  United States      Fairfield  ...  94533
#
#     Regiao       Id_Produto        Categoria Sub_Categoria  \
# ...

# %%
# Verificando as 5 ultimas linhas

df.tail(5)
# Out:
#         Id       Id_Pedido Data_Pedido Data_Envio      Modo_Envio Id_Cliente  \
# 9989  1760  CA-2014-141817  2014-01-05 2014-01-12  Standard Class   MB-18085
# 9990   740  CA-2014-112326  2014-01-04 2014-01-08  Standard Class   PO-19195
# 9991   741  CA-2014-112326  2014-01-04 2014-01-08  Standard Class   PO-19195
# 9992   742  CA-2014-112326  2014-01-04 2014-01-08  Standard Class   PO-19195
# 9993  7981  CA-2014-103800  2014-01-03 2014-01-07  Standard Class   DP-13000
#
#        Nome_Cliente     Segmento           Pais        Cidade  ...     CE  \
# 9989     Mick Brown     Consumer  United States  Philadelphia  ...  19143
# 9990  Phillina Ober  Home Office  United States    Naperville  ...  60540
# 9991  Phillina Ober  Home Office  United States    Naperville  ...  60540
# 9992  Phillina Ober  Home Office  United States    Naperville  ...  60540
# 9993  Darren Powers     Consumer  United States       Houston  ...  77095
#
# ...

# %%
# Estatísticas descritivas dos dados numéricos

df.describe(exclude='object')
# Out:
#                 Id                    Data_Pedido  \
# count  9994.000000                           9994
# mean   4997.500000  2016-04-30 00:07:12.259355392
# min       1.000000            2014-01-03 00:00:00
# 25%    2499.250000            2015-05-23 00:00:00
# 50%    4997.500000            2016-06-26 00:00:00
# 75%    7495.750000            2017-05-14 00:00:00
# max    9994.000000            2017-12-30 00:00:00
# std    2885.163629                            NaN
#
#                           Data_Envio            CE   Valor_Venda   Quantidade  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2016-05-03 23:06:58.571142912  55190.379428    229.858001     3.789574
# min              2014-01-07 00:00:00   1040.000000      0.444000     1.000000
# 25%              2015-05-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2016-06-29 00:00:00  56430.500000     54.490000     3.000000
# ...

# %%
df.describe(include='object')
# Out:
#              Id_Pedido      Modo_Envio Id_Cliente   Nome_Cliente  Segmento  \
# count             9994            9994       9994           9994      9994
# unique            5009               4        793            793         3
# top     CA-2017-100111  Standard Class   WB-21850  William Brown  Consumer
# freq                14            5968         37             37      5191
#
#                  Pais         Cidade      Estado Regiao       Id_Produto  \
# count            9994           9994        9994   9994             9994
# unique              1            531          49      4             1862
# top     United States  New York City  California   West  OFF-PA-10001970
# freq             9994            915        2001   3203               19
#
#               Categoria Sub_Categoria     Nome_Produto
# count              9994          9994             9994
# unique                3            17             1850
# top     Office Supplies       Binders  Staple envelope
# ...

# %%
# verificando se tem dados nulos porém detalhado
df.isna().sum().sort_values(ascending=False)
# Out:
# Id               0
# Id_Pedido        0
# Data_Pedido      0
# Data_Envio       0
# Modo_Envio       0
# Id_Cliente       0
# Nome_Cliente     0
# Segmento         0
# Pais             0
# Cidade           0
# Estado           0
# CE               0
# Regiao           0
# Id_Produto       0
# Categoria        0
# Sub_Categoria    0
# Nome_Produto     0
# Valor_Venda      0
# Quantidade       0
# Desconto         0
# Lucro            0
# dtype: int64

# %%
# Caso seja necessário que não foi esse caso 
# Podemos ver o percentual de nulos 
(df.isna().mean() * 100).round(2)
# Out:
# Id               0.0
# Id_Pedido        0.0
# Data_Pedido      0.0
# Data_Envio       0.0
# Modo_Envio       0.0
# Id_Cliente       0.0
# Nome_Cliente     0.0
# Segmento         0.0
# Pais             0.0
# Cidade           0.0
# Estado           0.0
# CE               0.0
# Regiao           0.0
# Id_Produto       0.0
# Categoria        0.0
# Sub_Categoria    0.0
# Nome_Produto     0.0
# Valor_Venda      0.0
# Quantidade       0.0
# Desconto         0.0
# Lucro            0.0
# dtype: float64
